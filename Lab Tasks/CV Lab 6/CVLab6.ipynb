# %%
from ultralytics import YOLO
import cv2

# Load a YOLOv8 model (pre-trained on COCO dataset)
model = YOLO('yolov8n.pt')  # You can replace 'n' with other sizes (s, m, l, x)

# Path to the video
video_path = r"C:\Users\Hp\Downloads\WhatsApp Video 2024-10-13 at 22.25.05_c67a1d8f.mp4"
output_path = r"C:\Users\Hp\Downloads\output_video.mp4"  # Output video file

# Open the video file
cap = cv2.VideoCapture(video_path)

# Check if video opened successfully
if not cap.isOpened():
    print("Error: Could not open video.")
    exit()

# Get video properties
fps = int(cap.get(cv2.CAP_PROP_FPS))  # Frames per second
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))  # Frame width
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))  # Frame height
fourcc = cv2.VideoWriter_fourcc(*'mp4v')  # Codec for .mp4

# Create VideoWriter object to save output video
out = cv2.VideoWriter(output_path, fourcc, fps, (width, height))

# Class names in COCO dataset
classNames = model.names

# Define the specific classes we are interested in
desired_classes = ['keyboard', 'laptop', 'mouse', 'monitor']

# Loop through the video frames
while True:
    ret, frame = cap.read()

    # Break the loop if we reach the end of the video
    if not ret:
        break

    # Detect objects in the frame
    results = model(frame)

    # Process results for each frame
    for r in results:
        for box in r.boxes:
            cls = int(box.cls[0])
            class_name = classNames[cls]

            if class_name in desired_classes:
                # Get bounding box coordinates
                x1, y1, x2, y2 = map(int, box.xyxy[0])

                # Draw the bounding box
                cv2.rectangle(frame, (x1, y1), (x2, y2), (255, 0, 255), 3)

                # Add class label and confidence
                confidence = round(float(box.conf[0]) * 100, 2)
                label = f"{class_name}: {confidence}%"
                cv2.putText(frame, label, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (255, 0, 0), 2)

    # Write the frame with detections to the output video
    out.write(frame)

# Release the video capture and writer objects
cap.release()
out.release()

print(f"Processed video saved to {output_path}")
# Out:
# 0: 384x640 1 tv, 2 laptops, 1 mouse, 86.5ms
# Speed: 3.0ms preprocess, 86.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cup, 1 tv, 1 laptop, 1 mouse, 92.5ms
# Speed: 3.0ms preprocess, 92.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cup, 1 cake, 2 tvs, 1 laptop, 1 mouse, 83.2ms
# Speed: 3.0ms preprocess, 83.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 tvs, 1 laptop, 1 mouse, 80.5ms
# Speed: 2.0ms preprocess, 80.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 tvs, 2 laptops, 1 mouse, 98.5ms
# Speed: 2.0ms preprocess, 98.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 1 mouse, 94.3ms
# Speed: 2.0ms preprocess, 94.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 tvs, 1 mouse, 80.9ms
# Speed: 2.0ms preprocess, 80.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cup, 1 cake, 2 tvs, 1 mouse, 75.1ms
# Speed: 3.0ms preprocess, 75.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cup, 2 tvs, 1 laptop, 1 mouse, 77.9ms
# Speed: 1.0ms preprocess, 77.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cup, 2 tvs, 1 mouse, 96.0ms
# Speed: 2.0ms preprocess, 96.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 cup, 1 tv, 1 mouse, 92.5ms
# Speed: 2.0ms preprocess, 92.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 tvs, 71.0ms
# Speed: 1.0ms preprocess, 71.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 tvs, 76.0ms
# Speed: 2.0ms preprocess, 76.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 tvs, 1 mouse, 86.1ms
# Speed: 2.0ms preprocess, 86.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 tvs, 81.2ms
# Speed: 1.0ms preprocess, 81.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 tvs, 1 mouse, 90.4ms
# Speed: 1.0ms preprocess, 90.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 dining table, 2 tvs, 1 mouse, 95.5ms
# Speed: 2.0ms preprocess, 95.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 tvs, 2 mouses, 88.1ms
# Speed: 2.0ms preprocess, 88.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 tvs, 1 laptop, 2 mouses, 1 keyboard, 75.5ms
# Speed: 2.0ms preprocess, 75.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 sports ball, 2 tvs, 1 laptop, 1 mouse, 2 keyboards, 76.6ms
# Speed: 2.0ms preprocess, 76.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 sports ball, 3 tvs, 1 laptop, 2 mouses, 2 keyboards, 85.4ms
# Speed: 1.0ms preprocess, 85.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 tvs, 1 laptop, 1 mouse, 2 keyboards, 84.5ms
# Speed: 2.0ms preprocess, 84.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 tvs, 1 laptop, 1 mouse, 3 keyboards, 80.1ms
# Speed: 1.0ms preprocess, 80.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 tvs, 1 laptop, 2 mouses, 3 keyboards, 90.2ms
# Speed: 1.0ms preprocess, 90.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 1 laptop, 3 mouses, 2 keyboards, 85.5ms
# Speed: 2.0ms preprocess, 85.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 1 laptop, 3 mouses, 2 keyboards, 102.5ms
# Speed: 2.0ms preprocess, 102.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 1 laptop, 3 mouses, 2 keyboards, 89.2ms
# Speed: 2.0ms preprocess, 89.2ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 1 laptop, 2 mouses, 2 keyboards, 98.2ms
# Speed: 3.0ms preprocess, 98.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 1 laptop, 3 mouses, 2 keyboards, 91.1ms
# Speed: 2.0ms preprocess, 91.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 sports ball, 1 tv, 1 laptop, 2 mouses, 2 keyboards, 89.1ms
# Speed: 2.0ms preprocess, 89.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 1 laptop, 2 mouses, 2 keyboards, 93.8ms
# Speed: 2.3ms preprocess, 93.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 sports ball, 1 tv, 1 laptop, 2 mouses, 2 keyboards, 94.5ms
# Speed: 4.3ms preprocess, 94.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 2 mouses, 1 keyboard, 96.5ms
# Speed: 2.0ms preprocess, 96.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 tvs, 1 laptop, 2 mouses, 1 keyboard, 88.0ms
# Speed: 2.5ms preprocess, 88.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 tvs, 2 mouses, 1 keyboard, 91.4ms
# Speed: 2.0ms preprocess, 91.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 tvs, 1 laptop, 2 mouses, 1 keyboard, 92.9ms
# Speed: 3.1ms preprocess, 92.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 2 mouses, 3 keyboards, 93.5ms
# Speed: 1.0ms preprocess, 93.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 2 mouses, 2 keyboards, 103.5ms
# Speed: 4.0ms preprocess, 103.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 1 mouse, 1 book, 91.2ms
# Speed: 2.0ms preprocess, 91.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 1 mouse, 92.5ms
# Speed: 2.0ms preprocess, 92.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 1 mouse, 103.1ms
# Speed: 2.0ms preprocess, 103.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 1 mouse, 85.3ms
# Speed: 3.0ms preprocess, 85.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 1 mouse, 84.5ms
# Speed: 1.0ms preprocess, 84.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 1 mouse, 91.1ms
# Speed: 1.0ms preprocess, 91.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 tvs, 1 mouse, 1 keyboard, 84.1ms
# Speed: 2.0ms preprocess, 84.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 tvs, 1 mouse, 1 keyboard, 84.4ms
# Speed: 2.0ms preprocess, 84.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 tvs, 2 mouses, 1 keyboard, 77.5ms
# Speed: 1.7ms preprocess, 77.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 tvs, 2 mouses, 1 keyboard, 80.5ms
# Speed: 2.0ms preprocess, 80.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 tvs, 2 mouses, 1 keyboard, 93.5ms
# Speed: 2.0ms preprocess, 93.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 tvs, 2 mouses, 1 keyboard, 88.6ms
# Speed: 1.0ms preprocess, 88.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 tvs, 1 mouse, 1 keyboard, 100.5ms
# Speed: 2.0ms preprocess, 100.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 tvs, 2 mouses, 1 keyboard, 118.2ms
# Speed: 1.0ms preprocess, 118.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 tvs, 2 mouses, 1 keyboard, 93.1ms
# Speed: 2.0ms preprocess, 93.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 tvs, 1 keyboard, 81.5ms
# Speed: 1.0ms preprocess, 81.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 tvs, 1 keyboard, 84.4ms
# Speed: 2.0ms preprocess, 84.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 tvs, 1 mouse, 1 keyboard, 102.7ms
# Speed: 1.0ms preprocess, 102.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 tvs, 1 keyboard, 82.6ms
# Speed: 2.0ms preprocess, 82.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 tvs, 1 mouse, 1 keyboard, 89.2ms
# Speed: 3.0ms preprocess, 89.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 tvs, 1 mouse, 1 keyboard, 92.5ms
# Speed: 3.0ms preprocess, 92.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 tvs, 1 keyboard, 89.8ms
# Speed: 2.0ms preprocess, 89.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 tvs, 1 mouse, 1 keyboard, 99.4ms
# Speed: 1.0ms preprocess, 99.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 tvs, 1 mouse, 1 keyboard, 89.5ms
# Speed: 2.0ms preprocess, 89.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 tvs, 1 mouse, 1 keyboard, 86.5ms
# Speed: 2.0ms preprocess, 86.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 tvs, 1 keyboard, 77.5ms
# Speed: 2.0ms preprocess, 77.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 tvs, 1 mouse, 1 keyboard, 86.5ms
# Speed: 1.0ms preprocess, 86.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 1 keyboard, 93.5ms
# Speed: 2.0ms preprocess, 93.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 1 keyboard, 81.2ms
# Speed: 2.0ms preprocess, 81.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tv, 1 keyboard, 87.1ms
# Speed: 2.0ms preprocess, 87.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 1 book, 87.2ms
# Speed: 2.0ms preprocess, 87.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 person, 1 tv, 1 book, 92.4ms
# Speed: 2.0ms preprocess, 92.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 2 keyboards, 1 book, 98.7ms
# Speed: 3.0ms preprocess, 98.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 2 keyboards, 102.5ms
# Speed: 3.0ms preprocess, 102.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 1 keyboard, 95.4ms
# Speed: 2.0ms preprocess, 95.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 1 keyboard, 96.0ms
# Speed: 2.0ms preprocess, 96.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 1 keyboard, 99.3ms
# Speed: 2.0ms preprocess, 99.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 1 keyboard, 94.5ms
# Speed: 1.0ms preprocess, 94.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 1 keyboard, 100.5ms
# Speed: 2.0ms preprocess, 100.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 1 keyboard, 116.6ms
# Speed: 1.0ms preprocess, 116.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 1 keyboard, 80.8ms
# Speed: 1.2ms preprocess, 80.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 95.5ms
# Speed: 2.0ms preprocess, 95.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 100.3ms
# Speed: 4.0ms preprocess, 100.3ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 tvs, 93.2ms
# Speed: 1.0ms preprocess, 93.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 95.5ms
# Speed: 2.0ms preprocess, 95.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 88.5ms
# Speed: 1.0ms preprocess, 88.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 98.5ms
# Speed: 1.0ms preprocess, 98.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 85.5ms
# Speed: 2.0ms preprocess, 85.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 tvs, 100.5ms
# Speed: 2.0ms preprocess, 100.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 90.0ms
# Speed: 2.5ms preprocess, 90.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 91.0ms
# Speed: 2.0ms preprocess, 91.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 83.5ms
# Speed: 2.0ms preprocess, 83.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 90.2ms
# Speed: 2.5ms preprocess, 90.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 83.0ms
# Speed: 1.0ms preprocess, 83.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 75.5ms
# Speed: 2.0ms preprocess, 75.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 92.8ms
# Speed: 2.0ms preprocess, 92.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 87.3ms
# Speed: 2.0ms preprocess, 87.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 91.2ms
# Speed: 1.0ms preprocess, 91.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 1 laptop, 92.1ms
# Speed: 2.0ms preprocess, 92.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 1 laptop, 95.5ms
# Speed: 2.0ms preprocess, 95.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 1 laptop, 85.5ms
# Speed: 4.0ms preprocess, 85.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 1 laptop, 1 keyboard, 94.5ms
# Speed: 2.0ms preprocess, 94.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 1 laptop, 99.5ms
# Speed: 1.0ms preprocess, 99.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 1 laptop, 82.1ms
# Speed: 2.0ms preprocess, 82.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 99.5ms
# Speed: 1.0ms preprocess, 99.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 2 laptops, 72.0ms
# Speed: 1.5ms preprocess, 72.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 1 laptop, 1 keyboard, 78.1ms
# Speed: 2.0ms preprocess, 78.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 2 laptops, 1 mouse, 1 keyboard, 85.2ms
# Speed: 2.0ms preprocess, 85.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 2 laptops, 1 mouse, 1 keyboard, 89.5ms
# Speed: 2.0ms preprocess, 89.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 86.6ms
# Speed: 1.0ms preprocess, 86.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 71.9ms
# Speed: 2.0ms preprocess, 71.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 78.1ms
# Speed: 1.0ms preprocess, 78.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 tv, 88.3ms
# Speed: 1.0ms preprocess, 88.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Processed video saved to C:\Users\Hp\Downloads\output_video.mp4
